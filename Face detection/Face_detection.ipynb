# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

# %%
img1=cv2.imread("/content/pic.jpg")

# %%
img1.shape
# Out:
# (609, 1024, 3)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x609 at 0x7FE461D4D7D0>

# %%
img1 = cv2.resize(img1, (500, 500))

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FE45F9CF650>

# %%
face_cascade = cv2.CascadeClassifier('/content/detection.xml')

# %%
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
  cv2.rectangle(img1,(x,y),(x+w,y+h),(255,0,0),2)
  roi_gray = gray[y:y+h, x:x+w]
  roi_color = img1[y:y+h, x:x+w]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FE45F9BA7D0>
